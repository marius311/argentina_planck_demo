# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pypico

# %%
pico = pypico.load_pico("/root/data/jcset.dat")

# %%
nmodels = 9
for i,ns in enumerate(linspace(0.95,0.99,nmodels)):
    params = pico.example_inputs()
    params['ns'] = ns
    plot(pico.get(**params)['dl_TT'],color=get_cmap('jet')(i/float(nmodels)),label='$n_s=%.3f$'%ns)

legend()    
xlabel(r'$\ell$',size=18)
ylabel(r'$D_\ell\,[\mu K^2]$',size=18)
